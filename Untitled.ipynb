# %%
import pandas as p
import matplotlib.pyplot as mpl
# Out:
# /home/jyu/miniconda3/envs/base1/lib/python3.7/importlib/_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
loan_data = p.read_csv('loan_data.csv',header=0)
ownership_data = p.read_csv('home_ownership_data.csv')

# %%
ownership_data
# Out:
#      member_id home_ownership
# 0      1030901       MORTGAGE
# 1      1247741       MORTGAGE
# 2      1261745       MORTGAGE
# 3      1264291           RENT
# 4      1269083           RENT
# ..         ...            ...
# 195    1306957            OWN
# 196    1311441           RENT
# 197    1311748           RENT
# 198    1313524           RENT
# 199    1314167           RENT
#
# [200 rows x 2 columns]

# %%
loan_data
# Out:
#      member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 0      1296599       5000         5000           4975.0   36 months     10.65
# 1      1314167       2500         2500           2500.0   60 months     15.27
# 2      1313524       2400         2400           2400.0   36 months     15.96
# 3      1277178      10000        10000          10000.0   36 months     13.49
# 4      1311748       3000         3000           3000.0   60 months     12.69
# ..         ...        ...          ...              ...         ...       ...
# 195    1301405      12000        12000          12000.0   36 months     14.27
# 196    1301397      25000        25000          25000.0   36 months     11.71
# 197    1299445       9000         9000           9000.0   36 months     12.69
# 198    1301395      13250        13250          13250.0   36 months     10.65
# 199    1293509      20000        20000          20000.0   36 months     13.49
#
# ...

# %%
joined = loan_data.join(ownership_data.set_index('member_id'),on='member_id')

# %%
joined.groupby('home_ownership')['loan_amnt'].mean().plot.bar()
